# %% [markdown]
# # London Crime by LSOA 2008 - 2016

# %% [markdown]
# Nama : Leticia
#
# Batch : 5
#
# Kode Peserta : PYTN-KS20-023
#
# Python for Data Science

# %% [markdown]
# #Persiapan data dan Menampilkan data

# %% [markdown]
# **Pengimportan file csv karena dikerjakan melalui Google Colab**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Persiapan library**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from PIL import Image
import folium

# %% [markdown]
# **Membaca data pada file .csv**

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/london_crime_by_lsoa.csv')

# %% [markdown]
# **Mengurutkan kembali data berdasarkan Tahun**

# %%
df.sort_values(by='year', ascending=True, axis=0, inplace=True)

# %% [markdown]
# **Membuat variabel df_1 untuk value = 1 dan menampilkannya**

# %%
df_1=df[df["value"] == 1]
df_1
# Out:
#           lsoa_code                 borough               major_category  \
# 1315473   E01002399              Hillingdon           Theft and Handling
# 2874646   E01003986               Southwark                      Robbery
# 8512166   E01000928                  Camden              Criminal Damage
# 8512202   E01001995                Haringey  Violence Against the Person
# 1315554   E01001876  Hammersmith and Fulham              Criminal Damage
# ...             ...                     ...                          ...
# 6170992   E01002215                  Harrow  Violence Against the Person
# 11948672  E01004426          Waltham Forest           Theft and Handling
# 4481298   E01001957  Hammersmith and Fulham  Violence Against the Person
# 6171393   E01000439                  Bexley           Theft and Handling
# 6171475   E01001309                  Ealing           Theft and Handling
#
#                        minor_category  value  year  month
# ...

# %% [markdown]
# **Menampilkan data 10 teratas dan 10 terbawah**

# %%
df_1.head(10)
# Out:
#           lsoa_code                 borough               major_category  \
# 1315473   E01002399              Hillingdon           Theft and Handling
# 2874646   E01003986               Southwark                      Robbery
# 8512166   E01000928                  Camden              Criminal Damage
# 8512202   E01001995                Haringey  Violence Against the Person
# 1315554   E01001876  Hammersmith and Fulham              Criminal Damage
# 2874608   E01002180                  Harrow                     Burglary
# 2874696   E01003692               Redbridge  Violence Against the Person
# 1315420   E01000865                  Camden              Criminal Damage
# 1315417   E01000911                  Camden              Criminal Damage
# 11363134  E01003848    Richmond upon Thames  Violence Against the Person
#
#                        minor_category  value  year  month
# 1315473      Theft From Motor Vehicle      1  2008      3
# ...

# %%
df_1.tail(10)
# Out:
#           lsoa_code                 borough               major_category  \
# 6171333   E01002182                  Harrow           Theft and Handling
# 6171000   E01000664                 Bromley                      Robbery
# 6170863   E01001886  Hammersmith and Fulham           Theft and Handling
# 6170904   E01001552                 Enfield              Criminal Damage
# 6170956   E01003503                  Newham  Violence Against the Person
# 6170992   E01002215                  Harrow  Violence Against the Person
# 11948672  E01004426          Waltham Forest           Theft and Handling
# 4481298   E01001957  Hammersmith and Fulham  Violence Against the Person
# 6171393   E01000439                  Bexley           Theft and Handling
# 6171475   E01001309                  Ealing           Theft and Handling
#
#                             minor_category  value  year  month
# 6171333                   Theft From Shops      1  2016      8
# ...

# %% [markdown]
# **Melihat informasi dari dataset**

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2141789 entries, 1315473 to 6171475
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 130.7+ MB

# %%
df_1.columns.values
# Out:
# array(['lsoa_code', 'borough', 'major_category', 'minor_category',
#        'value', 'year', 'month'], dtype=object)

# %%
df_1.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'),
#        dtype('int64'), dtype('int64')], dtype=object)

# %% [markdown]
# **Total baris dan kolom yang ada**

# %%
df_1.shape
# Out:
# (2141789, 7)

# %% [markdown]
# **Hasil:**
# 1. **Baris = 2.141.789 baris**
# 2. **Kolom = 7 kolom**

# %%
df_1.describe()
# Out:
#            value          year         month
# count  2141789.0  2.141789e+06  2.141789e+06
# mean         1.0  2.012015e+03  6.507797e+00
# std          0.0  2.599081e+00  3.425987e+00
# min          1.0  2.008000e+03  1.000000e+00
# 25%          1.0  2.010000e+03  4.000000e+00
# 50%          1.0  2.012000e+03  7.000000e+00
# 75%          1.0  2.014000e+03  9.000000e+00
# max          1.0  2.016000e+03  1.200000e+01

# %% [markdown]
# **Jumlah kejahatan yang terjadi setiap tahunnya**

# %%
x = df_1["year"].value_counts()
print(x)
# Out:
# 2016    246170
# 2015    241347
# 2008    240966
# 2009    238097
# 2014    237515
# 2010    235513
# 2011    234747
# 2012    234714
# 2013    232720
# Name: year, dtype: int64

# %% [markdown]
# **Jenis dan jumlah kejahatan besar**

# %%
major = df_1['major_category'].value_counts()
major
# Out:
# Theft and Handling             662379
# Violence Against the Person    544226
# Criminal Damage                353769
# Burglary                       263035
# Drugs                          138878
# Robbery                        110785
# Other Notifiable Offences       65925
# Fraud or Forgery                 1835
# Sexual Offences                   957
# Name: major_category, dtype: int64

# %%
major1 = df_1.pivot_table(values='value', index=['year'],columns=['major_category'], aggfunc=np.sum, fill_value=0)
major1
# Out:
# major_category  Burglary  Criminal Damage  Drugs  Fraud or Forgery  \
# year
# 2008               29367            44774  15568              1835
# 2009               29193            43518  15686                 0
# 2010               29471            41800  15863                 0
# 2011               29513            40220  16121                 0
# 2012               30222            37425  15845                 0
# 2013               30037            34805  15980                 0
# 2014               29071            36118  15286                 0
# 2015               28299            37394  14432                 0
# 2016               27862            37715  14097                 0
#
# major_category  Other Notifiable Offences  Robbery  Sexual Offences  \
# year
# 2008                                 6452    13099              957
# 2009                                 6587    12889                0
# 2010                                 6813    13241                0
# ...

# %% [markdown]
# **Jenis dan jumlah kejahatan kecil**

# %%
minor = df_1['minor_category'].value_counts()
minor
# Out:
# Burglary in a Dwelling                    154845
# Theft From Motor Vehicle                  151633
# Assault with Injury                       138647
# Other Theft                               136743
# Common Assault                            135116
# Harassment                                135016
# Criminal Damage To Motor Vehicle          124756
# Theft/Taking Of Motor Vehicle             122568
# Possession Of Drugs                       112104
# Burglary in Other Buildings               108190
# Criminal Damage To Dwelling                96217
# Personal Property                          92874
# Other Criminal Damage                      88923
# Other Theft Person                         77223
# Theft/Taking of Pedal Cycle                72838
# Wounding/GBH                               68261
# Other Notifiable                           61176
# Theft From Shops                           45207
# Criminal Damage To Other Building          43873
# ...

# %%
minor1 = df_1.pivot_table(values='value', index=['year'],columns=['minor_category'], aggfunc=np.sum, fill_value=0)
minor1
# Out:
# minor_category  Assault with Injury  Burglary in Other Buildings  \
# year
# 2008                          15104                        12594
# 2009                          15424                        12421
# 2010                          15249                        12390
# 2011                          15170                        12442
# 2012                          15459                        12737
# 2013                          14993                        12210
# 2014                          15644                        11481
# 2015                          15687                        11079
# 2016                          15917                        10836
#
# minor_category  Burglary in a Dwelling  Business Property  Common Assault  \
# year
# 2008                             16773               2432           14347
# 2009                             16772               2579           14511
# 2010                             17081               2504           14707
# ...

# %% [markdown]
# # Visualisasi Data

# %% [markdown]
# ## Area Plot

# %% [markdown]
# **Kategori kejahatan kecil di London dari tahun 2008-2016**

# %%
minor1.plot(kind='area',
            alpha=0.5,
            stacked=False,
            figsize=(20, 15),
            )

plt.title('Area Plot mengenai Kejahatan Kecil di London pada Tahun 2008 - 2016')
plt.xlabel('Tahun')
plt.ylabel('Total Kasus Kejahatan')
plt.show()

# %% [markdown]
# **Kesimpulan:**
# **Jenis kejahatan kecil yang paling banyak dilakukan adalah Burglary in a Dwelling yaitu dengan jumlah lebih dari 150.000 kejahatan**

# %% [markdown]
# ## Histograms

# %% [markdown]
# **Kejahatan besar yang paling banyak dan paling sedikit terjadi**

# %%
count, bin_edges = np.histogram(major, 15)
major.plot(kind ='hist',
           figsize=(20, 15),
           bins=15,
           alpha=0.5,
           xticks=bin_edges,
           )

plt.title('Kejahatan Besar di London Tahun 2008 - 2016')
plt.xlabel('Jumlah Kejahatan')
plt.ylabel('Jarak Tahun')
plt.show()

# %% [markdown]
# **Kesimpulan: Kejahatan besar yang paling banyak di London tahun 2008-2016 adalah "Theft and Handling" dan yang paling sedikit adalah "Sexual Offences".**

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# **Kasus kejahatan di Wilayah London pada Tahun 2008-2016**

# %%
borough = df_1['borough'].value_counts()
barv=borough[0:25]
barv.plot(kind='bar', figsize=(20,10), color='skyblue')

plt.title('Kasus Kejahatan di Wilayah London Tahun 2008 - 2016')
plt.xlabel('Wilayah')
plt.ylabel('Total Kejahatan')

plt.show()

# %% [markdown]
# **Kesimpulan: Dari 25 wilayah yang diambil, wilayah Croydon adalah wilayah dengan kejahatan paling banyak(>80.000) dan yang paling sedikit adalah Wilayah Barking and Dagenham(<60.000)**

# %%
x = df_1["year"].value_counts()
x.columns = ["year"]
y = x.sort_values()
y.plot(kind='barh', figsize=(20,10), color='skyblue')

plt.title('Kasus Kejahatan di City of London Tahun 2008 - 2016')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Kejahatan')

plt.show()

# %% [markdown]
# **Kesimpulan: Angka kejahatan paling tinggi terjadi pada tahun 2016 dan Angka kejahatan paling rendah adalah pada tahun 2013**

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# **Persentase kejahatan besar di London Tahun 2008-2016**

# %%
crimes = df_1['major_category'].value_counts()
major2 = pd.DataFrame(data=crimes.index, columns=["major_category"])
major2['values'] = crimes.values

fig = px.pie(major2, values='values', names='major_category', color_discrete_sequence=px.colors.qualitative.Pastel_r)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Kesimpulan: Persentase kasus kejahatan paling tinggi adalah 30,9% dan persentase paling rendah adalah 0,0447%**

# %%
colors_list = ['cyan','lightgreen','khaki','red','coral','teal','violet','navy','darkgrey']
explode_list = [0.1, 0, 0, 0, 0, 0, 0, 0.15, 0.3]
dfpie = df_1.groupby(['major_category']).sum()['value'].sort_values(ascending=False)
dfpie.plot(kind='pie',
           figsize=(15, 6),
           startangle=90,
           autopct='%1.3f%%',
           labels=None,
           colors=colors_list,
           pctdistance=1.12,
           explode=explode_list
           )
plt.title('Persentase Kejahatan Besar di London Tahun 2008 - 2016', y=1.12)
plt.ylabel('')
plt.legend(labels=dfpie.index, loc='upper right')
plt.axis('equal')

plt.show()
# Out:
# <ipython-input-335-91003da5524c>:3: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %% [markdown]
# **Kesimpulan: 3 kejahatan dengan persentase teratas adalah Theft and Handling(30,926%), Violence Against the Person(25,410%), dan Criminal Damage(16,517%)**

# %% [markdown]
# ## Box Plot

# %% [markdown]
# **Angka maksimal untuk kasus Drug Trafficking**

# %%
drugtraff = minor1['Drug Trafficking']
drugtraff.plot(kind='box', figsize=(10, 8))
# Out:
# <Axes: >

# %% [markdown]
# **Kesimpulan: Angka maksimal untuk kejahatan Drug Trafficking adalah hampir mencapai 2800**

# %% [markdown]
# ## Scatter Plot

# %%
scatter = minor1[['Theft From Motor Vehicle','Offensive Weapon']]
scatter = scatter.reset_index()
scatter
# Out:
# minor_category  year  Theft From Motor Vehicle  Offensive Weapon
# 0               2008                     16492              4300
# 1               2009                     16510              3411
# 2               2010                     16352              3208
# 3               2011                     16922              3102
# 4               2012                     17163              2511
# 5               2013                     16992              2642
# 6               2014                     17262              2786
# 7               2015                     17038              3176
# 8               2016                     16902              3673

# %%
a = scatter.plot(kind='scatter', x='year', y='Theft From Motor Vehicle', figsize=(10, 6), color='seagreen', label='Theft From Motor Vehicle')
b = scatter.plot(kind='scatter', x='year', y='Offensive Weapon', figsize=(10, 6), color='orange',label='Offensive Weapon', ax=a )

plt.title('Perbandingan antara Theft From Motor Vehicle dan Offensive Weapon di London Tahun 2008 - 2016')
plt.xlabel('Tahun')
plt.ylabel('Total Kasus')

plt.show()

# %% [markdown]
# **Kesimpulan: Untuk kejahatan Theft From Motor Vehicle memiliki sekitar lebih dari 16.000 kasus setiap tahunnya, sedangkan untuk kejahatan Offensive Weapon hanya memiliki sekitar 2000 sampai 4000 kasus setiap tahunnya.**

# %% [markdown]
# ## Word Clouds

# %% [markdown]
# **Menampilkan Jenis kejahatan minor dan major dalam bentuk Word Clouds**

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords=set(STOPWORDS)

# %%
minor_case = ' '.join(df_1.minor_category)

minor_wc = WordCloud(
    background_color='white',
    max_words=200,
    stopwords=stopwords
    )

minor_wc.generate(minor_case)

# %%
plt.imshow(minor_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
datamajor = ' '.join(df_1.major_category)
london_bridge = np.array(Image.open('/content/drive/MyDrive/Dataset/london_bridge.png'))

# %%
fig=plt.figure()
fig.set_figwidth(12)
fig.set_figheight(14)

plt.imshow(london_bridge, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
major_wc = WordCloud(background_color='white', max_words=300,
                     mask=london_bridge, stopwords=stopwords)
major_wc.generate(datamajor)

fig=plt.figure()
fig.set_figwidth(30)
fig.set_figheight(36)

plt.imshow(major_wc,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Folium Map

# %%
latitude = 51.509865
longitude = -0.118092

map_of_london = folium.Map(location=[latitude,longitude], zoom_start=12)
map_of_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map_of_london = folium.Map(location=[latitude,longitude], zoom_start=12, tiles="Stamen Terrain")
map_of_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Kesimpulan secara keseluruhan

# %% [markdown]
# 1. Jumlah Kejahatan paling banyak terjadi pada tahun 2016, dan yang paling sedikit terjadi pada tahun 2013.
# 2. Jenis kejahatan kecil jauh lebih banyak dibandingkan dengan jenis kejahatan besar.
# 3. Wilayah yang paling rawan mengalami kejahatan adalah Croydon, Lambeth, dan Ealing.
# 4. Kejahatan major yang paling banyak dilakukan adalah Theft and Handling dan yang paling sedikit adalah Sexual Offences
# 5. Kejahatan minor yang paling banyak dilakukan adalah Burglary in a Dwelling dan yang paling sedikit adalah Rape
