# %% [markdown]
# # London Crime by LSOA 2008 - 2016

# %% [markdown]
# Nama : Leticia
#
# Batch : 5
#
# Kode Peserta : PYTN-KS20-023
#
# Python for Data Science

# %% [markdown]
# #Persiapan data dan Menampilkan data

# %% [markdown]
# **Pengimportan file csv karena dikerjakan melalui Google Colab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Persiapan library**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from PIL import Image
import folium

# %% [markdown]
# **Membaca data pada file .csv**

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/london_crime_by_lsoa.csv')

# %% [markdown]
# **Mengurutkan kembali data berdasarkan Tahun**

# %%
df.sort_values(by='year', ascending=True, axis=0, inplace=True)

# %% [markdown]
# **Membuat variabel df_1 untuk value >= 1 dan menampilkannya**

# %%
df_1=df[df["value"] >= 1]
df_1
# Out:
#           lsoa_code                 borough               major_category  \
# 1315511   E01004204           Tower Hamlets  Violence Against the Person
# 2874646   E01003986               Southwark                      Robbery
# 8512166   E01000928                  Camden              Criminal Damage
# 8512169   E01002676                Hounslow                        Drugs
# 5807242   E01002999    Kingston upon Thames           Theft and Handling
# ...             ...                     ...                          ...
# 6171393   E01000439                  Bexley           Theft and Handling
# 6171437   E01000108    Barking and Dagenham                     Burglary
# 6171449   E01001915  Hammersmith and Fulham                        Drugs
# 11948567  E01002406              Hillingdon           Theft and Handling
# 6171475   E01001309                  Ealing           Theft and Handling
#
#                                   minor_category  value  year  month
# 1315511                           Common Assault      2  2008      9
# 2874646                        Business Property      1  2008      7
# 8512166                    Other Criminal Damage      1  2008      9
# 8512169                      Possession Of Drugs      2  2008      9
# 5807242                              Other Theft      2  2008     11
# ...                                          ...    ...   ...    ...
# 6171393              Theft/Taking of Pedal Cycle      1  2016     12
# 6171437                   Burglary in a Dwelling      3  2016      1
# 6171449                      Possession Of Drugs      3  2016      5
# 11948567  Motor Vehicle Interference & Tampering      5  2016     12
# 6171475                              Other Theft      1  2016      5
#
# [3419099 rows x 7 columns]

# %% [markdown]
# **Menampilkan data 10 teratas dan 10 terbawah**

# %%
df_1.head(10)
# Out:
#          lsoa_code                 borough               major_category  \
# 1315511  E01004204           Tower Hamlets  Violence Against the Person
# 2874646  E01003986               Southwark                      Robbery
# 8512166  E01000928                  Camden              Criminal Damage
# 8512169  E01002676                Hounslow                        Drugs
# 5807242  E01002999    Kingston upon Thames           Theft and Handling
# 8512202  E01001995                Haringey  Violence Against the Person
# 1315554  E01001876  Hammersmith and Fulham              Criminal Damage
# 2874608  E01002180                  Harrow                     Burglary
# 5807318  E01004444          Waltham Forest           Theft and Handling
# 8512129  E01003524                  Newham                     Burglary
#
#                    minor_category  value  year  month
# 1315511            Common Assault      2  2008      9
# 2874646         Business Property      1  2008      7
# 8512166     Other Criminal Damage      1  2008      9
# 8512169       Possession Of Drugs      2  2008      9
# 5807242               Other Theft      2  2008     11
# 8512202                Harassment      1  2008      7
# 1315554     Other Criminal Damage      1  2008      1
# 2874608    Burglary in a Dwelling      1  2008      2
# 5807318  Theft From Motor Vehicle      2  2008     12
# 8512129    Burglary in a Dwelling      2  2008      5

# %%
df_1.tail(10)
# Out:
#           lsoa_code                 borough               major_category  \
# 6171315   E01003319                Lewisham  Violence Against the Person
# 11948521  E01000072    Barking and Dagenham  Violence Against the Person
# 11948509  E01002394              Hillingdon                     Burglary
# 6171333   E01002182                  Harrow           Theft and Handling
# 11948593  E01002281                Havering           Theft and Handling
# 6171393   E01000439                  Bexley           Theft and Handling
# 6171437   E01000108    Barking and Dagenham                     Burglary
# 6171449   E01001915  Hammersmith and Fulham                        Drugs
# 11948567  E01002406              Hillingdon           Theft and Handling
# 6171475   E01001309                  Ealing           Theft and Handling
#
#                                   minor_category  value  year  month
# 6171315                           Common Assault      2  2016      7
# 11948521                          Common Assault      2  2016      6
# 11948509                  Burglary in a Dwelling      2  2016      6
# 6171333                         Theft From Shops      1  2016      8
# 11948593                Theft From Motor Vehicle      4  2016      7
# 6171393              Theft/Taking of Pedal Cycle      1  2016     12
# 6171437                   Burglary in a Dwelling      3  2016      1
# 6171449                      Possession Of Drugs      3  2016      5
# 11948567  Motor Vehicle Interference & Tampering      5  2016     12
# 6171475                              Other Theft      1  2016      5

# %% [markdown]
# **Melihat informasi dari dataset**

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3419099 entries, 1315511 to 6171475
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 208.7+ MB

# %%
df_1.columns.values
# Out:
# array(['lsoa_code', 'borough', 'major_category', 'minor_category',
#        'value', 'year', 'month'], dtype=object)

# %%
df_1.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'),
#        dtype('int64'), dtype('int64')], dtype=object)

# %% [markdown]
# **Total baris dan kolom yang ada**

# %%
x = df_1.shape[0]
y = df_1.shape[1]

print('Jumlah Baris: ', x, '\nJumlah Kolom: ', y)
# Out:
# Jumlah Baris:  3419099
# Jumlah Kolom:  7

# %%
df_1.describe()
# Out:
#               value          year         month
# count  3.419099e+06  3.419099e+06  3.419099e+06
# mean   1.885806e+00  2.011991e+03  6.511021e+00
# std    3.118902e+00  2.602550e+00  3.422459e+00
# min    1.000000e+00  2.008000e+03  1.000000e+00
# 25%    1.000000e+00  2.010000e+03  4.000000e+00
# 50%    1.000000e+00  2.012000e+03  7.000000e+00
# 75%    2.000000e+00  2.014000e+03  9.000000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %% [markdown]
# **Jumlah kejahatan yang terjadi setiap tahunnya**

# %%
x = df_1["year"].value_counts()
print(x)
# Out:
# 2016    392042
# 2008    391242
# 2009    383008
# 2015    381859
# 2010    379349
# 2011    378814
# 2012    377721
# 2014    370384
# 2013    364680
# Name: year, dtype: int64

# %% [markdown]
# **Jenis dan jumlah kejahatan besar**

# %%
major = df_1['major_category'].value_counts()
major
# Out:
# Theft and Handling             1136994
# Violence Against the Person     894859
# Criminal Damage                 466268
# Burglary                        441209
# Drugs                           231894
# Robbery                         163549
# Other Notifiable Offences        80569
# Fraud or Forgery                  2682
# Sexual Offences                   1075
# Name: major_category, dtype: int64

# %%
major1 = df_1.pivot_table(values='value', index=['year'],columns=['major_category'], aggfunc=np.sum, fill_value=0)
major1
# Out:
# major_category  Burglary  Criminal Damage  Drugs  Fraud or Forgery  \
# year
# 2008               88092            91872  68804              5325
# 2009               90619            85565  60549                 0
# 2010               86826            77897  58674                 0
# 2011               93315            70914  57550                 0
# 2012               93392            62158  51776                 0
# 2013               87222            56206  50278                 0
# 2014               76053            59279  44435                 0
# 2015               70489            62976  39785                 0
# 2016               68285            64071  38914                 0
#
# major_category  Other Notifiable Offences  Robbery  Sexual Offences  \
# year
# 2008                                10112    29627             1273
# 2009                                10644    29568                0
# 2010                                10768    32341                0
# 2011                                10264    36679                0
# 2012                                10675    35260                0
# 2013                                10811    29337                0
# 2014                                13037    22150                0
# 2015                                14229    21383                0
# 2016                                15809    22528                0
#
# major_category  Theft and Handling  Violence Against the Person
# year
# 2008                        283692                       159844
# 2009                        279492                       160777
# 2010                        290924                       157894
# 2011                        309292                       146901
# 2012                        334054                       150014
# 2013                        306372                       146181
# 2014                        279880                       185349
# 2015                        284022                       218740
# 2016                        294133                       232381

# %% [markdown]
# **Jenis dan jumlah kejahatan kecil**

# %%
minor = df_1['minor_category'].value_counts()
minor
# Out:
# Other Theft                               297281
# Theft From Motor Vehicle                  291839
# Burglary in a Dwelling                    278792
# Assault with Injury                       244990
# Harassment                                243827
# Common Assault                            231398
# Possession Of Drugs                       201464
# Criminal Damage To Motor Vehicle          179380
# Theft/Taking Of Motor Vehicle             163069
# Burglary in Other Buildings               162417
# Personal Property                         144078
# Other Theft Person                        121674
# Criminal Damage To Dwelling               121592
# Other Criminal Damage                     112449
# Theft/Taking of Pedal Cycle               104947
# Theft From Shops                           94947
# Wounding/GBH                               90482
# Other Notifiable                           75483
# Criminal Damage To Other Building          52847
# Other violence                             50620
# Motor Vehicle Interference & Tampering     48769
# Offensive Weapon                           32623
# Drug Trafficking                           27592
# Business Property                          19471
# Handling Stolen Goods                      14468
# Going Equipped                              5086
# Other Drugs                                 2838
# Counted per Victim                          1630
# Other Fraud & Forgery                       1052
# Murder                                       919
# Other Sexual                                 819
# Rape                                         256
# Name: minor_category, dtype: int64

# %%
minor1 = df_1.pivot_table(values='value', index=['year'],columns=['minor_category'], aggfunc=np.sum, fill_value=0)
minor1
# Out:
# minor_category  Assault with Injury  Burglary in Other Buildings  \
# year
# 2008                          56586                        31437
# 2009                          55297                        30434
# 2010                          54173                        29703
# 2011                          50768                        30876
# 2012                          50369                        31676
# 2013                          39929                        30685
# 2014                          45677                        27078
# 2015                          48164                        25833
# 2016                          50038                        25289
#
# minor_category  Burglary in a Dwelling  Business Property  Common Assault  \
# year
# 2008                             56655               2964           37356
# 2009                             60185               3115           39671
# 2010                             57123               3041           41591
# 2011                             62439               2685           40502
# 2012                             61716               2450           39246
# 2013                             56537               2026           37882
# 2014                             48975               1642           51244
# 2015                             44656               1718           61758
# 2016                             42996               1654           64440
#
# minor_category  Counted per Victim  Criminal Damage To Dwelling  \
# year
# 2008                          3840                        23519
# 2009                             0                        22475
# 2010                             0                        20253
# 2011                             0                        18037
# 2012                             0                        15330
# 2013                             0                        13512
# 2014                             0                        13391
# 2015                             0                        13648
# 2016                             0                        13951
#
# minor_category  Criminal Damage To Motor Vehicle  \
# year
# 2008                                       41693
# 2009                                       36621
# 2010                                       32907
# 2011                                       29494
# 2012                                       25777
# 2013                                       23452
# 2014                                       24137
# 2015                                       25595
# 2016                                       25787
#
# minor_category  Criminal Damage To Other Building  Drug Trafficking  ...  \
# year                                                                 ...
# 2008                                         9011              4203  ...
# 2009                                         8348              4172  ...
# 2010                                         7962              4252  ...
# 2011                                         7445              4460  ...
# 2012                                         6753              3964  ...
# 2013                                         6367              4151  ...
# 2014                                         6641              3830  ...
# 2015                                         6776              3395  ...
# 2016                                         6700              3392  ...
#
# minor_category  Other Theft Person  Other violence  Personal Property  \
# year
# 2008                         24453            7721              26663
# 2009                         27549            7571              26453
# 2010                         29547            6947              29300
# 2011                         36090            6414              33994
# 2012                         46585            6623              32810
# 2013                         44964            7628              27311
# 2014                         30957            7785              20508
# 2015                         33829            9501              19665
# 2016                         34868           10588              20874
#
# minor_category  Possession Of Drugs  Rape  Theft From Motor Vehicle  \
# year
# 2008                          64228   268                     76570
# 2009                          56070     0                     68856
# 2010                          54026     0                     69709
# 2011                          52769     0                     69604
# 2012                          47491     0                     68198
# 2013                          45755     0                     63509
# 2014                          40309     0                     52167
# 2015                          36097     0                     50024
# 2016                          35203     0                     51319
#
# minor_category  Theft From Shops  Theft/Taking Of Motor Vehicle  \
# year
# 2008                       32857                          28303
# 2009                       36349                          24476
# 2010                       36935                          24890
# 2011                       36351                          26161
# 2012                       36562                          22464
# 2013                       36441                          20377
# 2014                       40141                          21653
# 2015                       42549                          21848
# 2016                       46957                          26366
#
# minor_category  Theft/Taking of Pedal Cycle  Wounding/GBH
# year
# 2008                                  15895          8701
# 2009                                  20721         10005
# 2010                                  19726          8033
# 2011                                  20885          7628
# 2012                                  21339          7151
# 2013                                  18708         15526
# 2014                                  17186         21556
# 2015                                  16513         23431
# 2016                                  18001         23525
#
# [9 rows x 32 columns]

# %% [markdown]
# # Visualisasi Data

# %% [markdown]
# ## Area Plot

# %% [markdown]
# **Kategori kejahatan kecil di London dari tahun 2008-2016**

# %%
minor1.plot(kind='area',
            alpha=0.5,
            stacked=False,
            figsize=(20, 15),
            )

plt.title('Area Plot mengenai Kejahatan Kecil di London pada Tahun 2008 - 2016')
plt.xlabel('Tahun')
plt.ylabel('Total Kasus Kejahatan')
plt.show()

# %% [markdown]
# **Kesimpulan:**
# **Jenis kejahatan kecil yang paling banyak dilakukan adalah Other Theft**

# %% [markdown]
# ## Histograms

# %% [markdown]
# **Kejahatan besar yang paling banyak dan paling sedikit terjadi**

# %%
count, bin_edges = np.histogram(major1, 12)
major1.plot(kind ='hist',
           figsize=(20, 15),
           bins=15,
           alpha=0.5,
           xticks=bin_edges,
           )

plt.title('Kejahatan Besar di London Tahun 2008 - 2016')
plt.xlabel('Jumlah Kejahatan')
plt.ylabel('Jarak Tahun')
plt.show()

# %% [markdown]
# **Kesimpulan: Kejahatan besar yang paling banyak di London tahun 2008-2016 adalah "Theft and Handling" dan yang paling sedikit adalah "Sexual Offences".**

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# **Kasus kejahatan di Wilayah London pada Tahun 2008-2016**

# %%
borough = df_1['borough'].value_counts()
barv=borough[0:25]
barv.plot(kind='bar', figsize=(20,10), color='skyblue')

plt.title('Kasus Kejahatan di Wilayah London Tahun 2008 - 2016')
plt.xlabel('Wilayah')
plt.ylabel('Total Kejahatan')

plt.show()

# %% [markdown]
# **Kesimpulan: Dari 25 wilayah yang diambil, wilayah Lambeth adalah wilayah dengan kejahatan paling banyak(hampir mencapai 160.000) dan yang paling sedikit adalah Wilayah Havering(>80.000)**

# %%
x = df_1["year"].value_counts()
x.columns = ["year"]
y = x.sort_values()
y.plot(kind='barh', figsize=(20,10), color='skyblue')

plt.title('Kasus Kejahatan di City of London Tahun 2008 - 2016')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Kejahatan')

plt.show()

# %% [markdown]
# **Kesimpulan: Angka kejahatan paling tinggi terjadi pada tahun 2016 dan Angka kejahatan paling rendah adalah pada tahun 2013**

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# **Persentase kejahatan besar di London Tahun 2008-2016**

# %%
crimes = df_1['major_category'].value_counts()
major2 = pd.DataFrame(data=crimes.index, columns=["major_category"])
major2['values'] = crimes.values

fig = px.pie(major2, values='values', names='major_category', color_discrete_sequence=px.colors.qualitative.Pastel_r)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6e8862ed-d491-4218-be98-bbc06f932619" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e8862ed-d491-4218-be98-bbc06f932619")) {                    Plotly.newPlot(                        "6e8862ed-d491-4218-be98-bbc06f932619",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"major_category=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Theft and Handling","Violence Against the Person","Criminal Damage","Burglary","Drugs","Robbery","Other Notifiable Offences","Fraud or Forgery","Sexual Offences"],"legendgroup":"","name":"","showlegend":true,"values":[1136994,894859,466268,441209,231894,163549,80569,2682,1075],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sc ...

# %% [markdown]
# **Kesimpulan: Persentase kasus kejahatan paling tinggi adalah 33,33% dan persentase paling rendah adalah 0,0314%**

# %%
colors_list = ['cyan','lightgreen','khaki','red','coral','teal','violet','navy','darkgrey']
explode_list = [0.08, 0, 0, 0, 0, 0, 0, 0.15, 0.3]
dfpie = df_1.groupby(['major_category']).sum()['value'].sort_values(ascending=False)
dfpie.plot(kind='pie',
           figsize=(15, 6),
           startangle=90,
           autopct='%1.3f%%',
           labels=None,
           colors=colors_list,
           pctdistance=1.12,
           explode=explode_list
           )
plt.title('Persentase Kejahatan Besar di London Tahun 2008 - 2016', y=1.12)
plt.ylabel('')
plt.legend(labels=dfpie.index, loc='upper right')
plt.axis('equal')

plt.show()
# Out:
# <ipython-input-46-725f00e862be>:3: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %% [markdown]
# **Kesimpulan: 3 kejahatan dengan persentase paling tinggi adalah Theft and Handling(41,284%), Violence Against the Person(24,165%), dan Burglary(11,699%)**

# %% [markdown]
# ## Box Plot

# %% [markdown]
# **Angka maksimal untuk kasus Drug Trafficking**

# %%
drugtraff = minor1['Drug Trafficking']
drugtraff.plot(kind='box', figsize=(10, 8))
# Out:
# <Axes: >

# %% [markdown]
# **Kesimpulan: Angka minimal untuk kejahatan Drug Trafficking adalah sekitar 3400 kasus, dan angka maksimalnya adalah >4400**

# %% [markdown]
# ## Scatter Plot

# %%
scatter = minor1[['Theft From Motor Vehicle','Offensive Weapon']]
scatter = scatter.reset_index()
scatter
# Out:
# minor_category  year  Theft From Motor Vehicle  Offensive Weapon
# 0               2008                     76570              5961
# 1               2009                     68856              4520
# 2               2010                     69709              4229
# 3               2011                     69604              3991
# 4               2012                     68198              3134
# 5               2013                     63509              3315
# 6               2014                     52167              3676
# 7               2015                     50024              4144
# 8               2016                     51319              5013

# %%
a = scatter.plot(kind='scatter', x='year', y='Theft From Motor Vehicle', figsize=(10, 6), color='seagreen', label='Theft From Motor Vehicle')
b = scatter.plot(kind='scatter', x='year', y='Offensive Weapon', figsize=(10, 6), color='orange',label='Offensive Weapon', ax=a )

plt.title('Perbandingan antara Theft From Motor Vehicle dan Offensive Weapon di London Tahun 2008 - 2016')
plt.xlabel('Tahun')
plt.ylabel('Total Kasus')

plt.show()

# %% [markdown]
# **Kesimpulan: Tidak ada korelasi antar 2 jenis kasus kejahatan kecil di atas. Tetapi dapat dilihat bahwa angka kejahatan Theft From Motor Vehicle semakin menurun dari Tahun ke Tahun (titik hijau yang semakin turun).**

# %% [markdown]
# ## Word Clouds

# %% [markdown]
# **Menampilkan Jenis kejahatan minor dan major dalam bentuk Word Clouds**

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords=set(STOPWORDS)

# %%
minor_case = ' '.join(df_1.minor_category)

minor_wc = WordCloud(
    background_color='white',
    max_words=200,
    stopwords=stopwords
    )

minor_wc.generate(minor_case)

# %%
plt.imshow(minor_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
datamajor = ' '.join(df_1.major_category)
london_bridge = np.array(Image.open('/content/drive/MyDrive/Dataset/london_bridge.png'))

# %%
fig=plt.figure()
fig.set_figwidth(12)
fig.set_figheight(14)

plt.imshow(london_bridge, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
major_wc = WordCloud(background_color='white', max_words=300,
                     mask=london_bridge, stopwords=stopwords)
major_wc.generate(datamajor)

fig=plt.figure()
fig.set_figwidth(30)
fig.set_figheight(36)

plt.imshow(major_wc,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Folium Map

# %%
latitude = 51.509865
longitude = -0.118092

map_of_london = folium.Map(location=[latitude,longitude], zoom_start=12)
map_of_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6005c7f399b3f179eaa244c1be1691e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6005c7f399b3f179eaa244c1be1691e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6005c7f399b3f179eaa244c1be1691e5 = L.map(
#                 &quot;map_6005c7f399b3f179eaa244c1be1691e5&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e8c3a6bbb909d8dba1e040b9fd70446 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6005c7f399b3f179eaa244c1be1691e5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_of_london = folium.Map(location=[latitude,longitude], zoom_start=12, tiles="Stamen Terrain")
map_of_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbdc5ec256da9c755b6a8fb1d36613cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbdc5ec256da9c755b6a8fb1d36613cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbdc5ec256da9c755b6a8fb1d36613cd = L.map(
#                 &quot;map_dbdc5ec256da9c755b6a8fb1d36613cd&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b927d5ba66bedf7ad4f0555c073bb5d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dbdc5ec256da9c755b6a8fb1d36613cd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Kesimpulan secara keseluruhan

# %% [markdown]
# 1. **Tren Kejahatan Tahunan:**
# * Dalam data kejahatan kita, kita dapat melihat bahwa jumlah kejahatan paling tinggi terjadi pada tahun 2016. Artinya, pada tahun tersebut, lebih banyak insiden kejahatan tercatat dalam data kita dibandingkan tahun-tahun lainnya.
# * Di sisi lain, tahun 2013 mencatat jumlah kejahatan paling sedikit dalam data kita. Ini berarti pada tahun tersebut, tingkat kejahatan relatif lebih rendah dibandingkan tahun lainnya.
#
# 2. **Perbandingan Jenis Kejahatan**
# * Saat kita mengkategorikan jenis kejahatan, kita melihat bahwa jenis kejahatan kecil jauh lebih banyak dibandingkan dengan jenis kejahatan besar.
#
# 3. **Wilayah Rawan Kejahatan**
# * Wilayah-wilayah yang paling rawan mengalami kejahatan adalah Lambeth,Croydon, dan Southwark. Artinya, dalam wilayah-wilayah ini, kita melihat jumlah kejahatan yang lebih tinggi dibandingkan dengan wilayah lainnya dalam data kita.
#
# 4. **Kejahatan Mayor**
# * Dalam kategori kejahatan mayor, Theft and Handling merupakan jenis kejahatan yang paling banyak terjadi dalam data kita. Ini berarti tindak kejahatan seperti pencurian dan pemrosesan barang curian adalah yang paling sering dilaporkan.
# * Di sisi lain, jenis kejahatan Sexual Offences adalah yang paling sedikit terjadi. Hal ini menunjukkan bahwa insiden-insiden kejahatan seksual lebih jarang terjadi dalam data kita.
#
# 5. **Kejahatan Minor**
# * Dalam kategori kejahatan minor, Other Theft adalah jenis kejahatan yang paling banyak terjadi. Ini mengindikasikan bahwa perampokan di tempat tinggal (rumah) adalah yang paling sering tercatat dalam data.
# * Sebaliknya, jenis kejahatan Rape adalah yang paling sedikit terjadi dalam data kita. Ini menunjukkan bahwa kasus-kasus kejahatan jenis ini terjadi lebih jarang. jenis kejahatan Rape adalah yang paling sedikit terjadi dalam data kita. Ini menunjukkan bahwa kasus-kasus kejahatan jenis ini terjadi lebih jarang.
